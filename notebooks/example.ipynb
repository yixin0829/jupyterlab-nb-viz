# %% [markdown]
# # Example Notebook
#
# Example notebook for testing cell linking feature.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Section 2

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Section 2.1

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
plt.figure()
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# Some insights here.
