# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('../datasets/1-ibm-hr.csv')

# %%
sns.barplot(x='Attrition', y='Age', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='Age'>

# %%
df_overtime_no= df[df["OverTime"]=="No"]
sns.boxplot(df_overtime_no, x="JobInvolvement", y="MonthlyIncome", hue="Attrition")
# Out:
# <Axes: xlabel='JobInvolvement', ylabel='MonthlyIncome'>
