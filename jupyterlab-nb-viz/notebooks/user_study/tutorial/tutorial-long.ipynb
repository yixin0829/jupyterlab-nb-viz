# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
df = pd.read_csv("../datasets/3-hr-analytics-aug_train.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
sns.catplot(y="target", data=df, kind="count")

# %%
sns.countplot(x= 'education_level' ,data=df, hue='target')
# Out:
# <Axes: xlabel='education_level', ylabel='count'>

# %%
sns.countplot(data=df, x='gender', hue='target', palette='rocket')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# Some insights about "gender", "education_level" and "target".

# %%
sns.boxplot(data=df, x='target', y='training_hours', palette='rocket')
# Out:
# <Axes: xlabel='target', ylabel='training_hours'>

# %% [markdown]
# Some insights about "target" and "training hours".

# %%
sns.barplot(x='relevent_experience', y='training_hours', data=df, hue='target')
# Out:
# <Axes: xlabel='relevent_experience', ylabel='training_hours'>

# %%
sns.barplot(x='education_level', y='training_hours', data=df, hue='target')
# Out:
# <Axes: xlabel='education_level', ylabel='training_hours'>

# %%
sns.barplot(x='major_discipline', y='training_hours', data=df, hue='target')
# Out:
# <Axes: xlabel='major_discipline', ylabel='training_hours'>

# %%
sns.boxplot(y="training_hours", data=df)
# Out:
# <Axes: ylabel='training_hours'>

# %%
sns.countplot(x='major_discipline' ,data=df, hue='target')
# Out:
# <Axes: xlabel='major_discipline', ylabel='count'>
